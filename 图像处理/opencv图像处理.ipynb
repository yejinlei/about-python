# %% [markdown]
# # opencv图像处理

# %% [markdown]
# ## 读取图像

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
# %matplotlib inline

im = cv2.imread(r"..\images\lena_full.png")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
fig = plt.subplots(figsize=(im.shape[0]/50, im.shape[1]/50))
plt.imshow(im)
